# %%
# %load_ext autoreload
# %autoreload 2

import cv2

# %% [markdown]
# ### GPU based matched filtering.
# Work in progress
#
# To run
#
# <code>
# source config.bash
# </code>

# %% [markdown]
# #### Perform tensorflow (GPU) based matched filtering on test image

# %%
import tensorflow_mf as tmf

testImage,corr = tmf.test0()

fig, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(testImage,cmap="gray")
ax2.imshow(corr,cmap="gray")
# Out:
# tensorflow:0.22523522377s
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:1352: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# #### Perform tensorflow (GPU) based matched filtering on test image

# %%
testImage,corr = tmf.test1()

fig, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(testImage,cmap="gray")
ax2.imshow(corr,cmap="gray")
# Out:
# tensorflow:0.242406129837s

# %% [markdown]
# #### Big ass image

# %%
if 1:
  testImage = tmf.LoadImage(maxDim = 1000)
  dFilter = tmf.MakeFilter()
  corr = tmf.MF(testImage,dFilter,useGPU=True)
  tmf.writer(corr,name="corr.tif")  
  tmf.writer(testImage,name="subs.tif")
# Out:
# tensorflow:0.39823102951s

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(testImage,cmap="gray")
ax2.imshow(corr,cmap="gray")

# %% [markdown]
# ### Dylan Testing

# %%
if 1:
    import sys
    sys.path.append("/home/AD/dfco222/scratchKafka/gpu_detect/")
    import util
    testImage = util.ReadImg("/home/AD/dfco222/scratchKafka/gpu_detect/testingNotchFilter.png",renorm=False,cvtColor=True)
    dFilter = cv2.imread("../myoimages/WTFilter.png")
    dFilter = np.asarray(cv2.cvtColor(dFilter, cv2.COLOR_BGR2GRAY),dtype=float)
    dFilter /= np.float(np.max(dFilter))
    
    filterHold = np.zeros((26,26))
    filterHold[:,3:-3] = dFilter
    
    corr = tmf.MF(testImage,filterHold,useGPU=True)
# Out:
# tensorflow:11.3011350632s

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(testImage,cmap="gray")
ax2.imshow(corr,cmap="gray")
