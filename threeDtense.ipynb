# %%
# %load_ext autoreload
# %autoreload 2

import cv2

# %%
pwd
# Out:
# u'/home/AD/srbl226/tensing/gpu_detect'

# %% [markdown]
# ### GPU based matched filtering.
#
#
#
# To run
# <code>
# source config.bash
# </code>

# %%
height = 50

# %%
import threeDtense as tmf

# %% [markdown]
# #### Perform tensorflow (GPU) based matched filtering on 3D test image
# Same as 2D but cross product to raise the information up a level

# %%
### I am about to reduce "thickness" on the right half of the image by 50%


testImage,corr = tmf.test0()
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(testImage[:,:,0],cmap="gray")
ax2.imshow(corr[:,:,0],cmap="gray")
# Out:
# Made test Image
# fdim 14
# PRE FILTER
# tensorflow:0.173135042191s
# POST FILTER
# Stubbornly refusing to do anything since 3D

# %%
np.shape(corr)
# Out:
# (200, 200, 50)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(testImage[:,:,28],cmap="gray")
ax2.imshow(corr[:,:,28],cmap="gray")

# %% [markdown]
# #### Perform tensorflow (GPU) based matched filtering on test image

# %%
testImage,corr, filt = tmf.test1()

fig, (ax1, ax2, ax3) = plt.subplots(1,3)
ax1.imshow(testImage,cmap="gray")
ax2.imshow(corr,cmap="gray")
ax3.imshow(filt,cmap="gray")
# Out:
# tensorflow:0.117722988129s

# %% [markdown]
# #### Big ass image

# %%
if 1:
  testImage = tmf.LoadImage(maxDim = 1000)
  dFilter = tmf.MakeFilter()
  corr = tmf.MF(testImage,dFilter,useGPU=True)
  tmf.writer(corr,name="corr.tif")  
  tmf.writer(testImage,name="subs.tif")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-10-70366bcb2df8> in <module>()
#       2   testImage = tmf.LoadImage(maxDim = 1000)
#       3   dFilter = tmf.MakeFilter()
# ----> 4   corr = tmf.MF(testImage,dFilter,useGPU=True)
#       5   tmf.writer(corr,name="corr.tif")
#       6   tmf.writer(testImage,name="subs.tif")
#
# /home/AD/srbl226/tensing/gpu_detect/tensorflow_mf.pyc in MF(dImage, dFilter, useGPU)
#     163     if useGPU:
#     164         # NOTE: I pass in an 'nrots' argument, but it doesn't actually do anything (e.g. 'some assembly required')
# --> 165        corr,tElapsed = doTFloop(dImage,filt,nrots=1)
#     166        corr = np.real(corr)
#     167     else:
#
# /home/AD/srbl226/tensing/gpu_detect/tensorflow_mf.pyc in doTFloop(img, mFs, nrots)
#     143     final, mfo,cnt= tf.while_loop(condition, body,
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(testImage,cmap="gray")
ax2.imshow(corr,cmap="gray")
